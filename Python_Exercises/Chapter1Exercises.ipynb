# %% [markdown]
# Exercise 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Print('Hello world!') - the function "Print" in a code should be a small letter "p" not big letter "P.
print('Hello world!')
# Out:
# Hello world!

# %%
#print'Hello world!') - there is a missing pair of parenthesis.
print('Hello world!')
# Out:
# Hello world!

# %%
#print('Hello world!) - there is a missing single quote.
print('Hello world!')
# Out:
# Hello world!

# %%
#print('Hello world!'') - unterminated string, in order to correct the error remove the extra single quote.
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)

# since x has a value of 43 then it added by 1 so the output is 44
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
#x = 43
#x = X + 1 - since the variable name is a small letter x then it should use it consistently, there is an error because big letter X is not a variable name it should change into a small letter x to correct the error.
#print(x)
